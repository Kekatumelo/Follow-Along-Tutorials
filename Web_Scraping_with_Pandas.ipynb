# %%
import pandas as pd

# %% [markdown]
# # Read a .csv from a URL with Pandas

# %% [markdown]
# ##### Target website" https://www.football-data.co.uk/data.php

# %%
# reading 1 csv file from the website
df_premier25=pd.read_csv('https://www.football-data.co.uk/mmz4281/2425/E0.csv')

# %%
df_premier25
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  16/08/2024  20:00     Man United       Fulham     1     0   H     0
# 1    E0  17/08/2024  12:30        Ipswich    Liverpool     0     2   A     0
# 2    E0  17/08/2024  15:00        Arsenal       Wolves     2     0   H     1
# 3    E0  17/08/2024  15:00        Everton     Brighton     0     3   A     0
# 4    E0  17/08/2024  15:00      Newcastle  Southampton     1     0   H     1
# ..   ..         ...    ...            ...          ...   ...   ...  ..   ...
# 375  E0  25/05/2025  16:00      Newcastle      Everton     0     1   A     0
# 376  E0  25/05/2025  16:00  Nott'm Forest      Chelsea     0     1   A     0
# 377  E0  25/05/2025  16:00    Southampton      Arsenal     1     2   A     0
# 378  E0  25/05/2025  16:00      Tottenham     Brighton     1     4   A     1
# 379  E0  25/05/2025  16:00         Wolves    Brentford     1     1   D     0
#
# ...

# %%
df_premier25.rename(columns={'FTHG':'home_goals',
                             'FTAG':'away_goals'},inplace=True)

# %% [markdown]
# # Read .csv from multiple URLs with Pandas

# %%
'https://www.football-data.co.uk/mmz4281/2425/E0.csv'
'https://www.football-data.co.uk/mmz4281/2425/E1.csv'
'https://www.football-data.co.uk/mmz4281/2425/E2.csv'
'https://www.football-data.co.uk/mmz4281/2425/E3.csv'
'https://www.football-data.co.uk/mmz4281/2425/EC.csv'

# %%
# Create a root variable
root = "https://www.football-data.co.uk/mmz4281/"

# %%
leagues = ['E0','E1','E2','E3','EC']
frames = []
for league in leagues:
  df = pd.read_csv(root +'2425/'+league+'.csv' )
  frames.append(df)

# %%
len(frames)
# Out:
# 5

# %%
frames[0]
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  16/08/2024  20:00     Man United       Fulham     1     0   H     0
# 1    E0  17/08/2024  12:30        Ipswich    Liverpool     0     2   A     0
# 2    E0  17/08/2024  15:00        Arsenal       Wolves     2     0   H     1
# 3    E0  17/08/2024  15:00        Everton     Brighton     0     3   A     0
# 4    E0  17/08/2024  15:00      Newcastle  Southampton     1     0   H     1
# ..   ..         ...    ...            ...          ...   ...   ...  ..   ...
# 375  E0  25/05/2025  16:00      Newcastle      Everton     0     1   A     0
# 376  E0  25/05/2025  16:00  Nott'm Forest      Chelsea     0     1   A     0
# 377  E0  25/05/2025  16:00    Southampton      Arsenal     1     2   A     0
# 378  E0  25/05/2025  16:00      Tottenham     Brighton     1     4   A     1
# 379  E0  25/05/2025  16:00         Wolves    Brentford     1     1   D     0
#
# ...

# %%
frames[4]
# Out:
#     Div        Date   Time     HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    EC  10/08/2024  15:00    Aldershot  Forest Green     3     3   D     2
# 1    EC  10/08/2024  15:00   Altrincham        Woking     1     0   H     1
# 2    EC  10/08/2024  15:00   Boston Utd      Rochdale     0     3   A     0
# 3    EC  10/08/2024  15:00  Dag and Red    Wealdstone     2     1   H     0
# 4    EC  10/08/2024  15:00        Fylde      Solihull     3     2   H     1
# ..   ..         ...    ...          ...           ...   ...   ...  ..   ...
# 547  EC  05/05/2025  15:00   Maidenhead    Boston Utd     3     0   H     1
# 548  EC  05/05/2025  15:00       Oldham     Ebbsfleet     2     0   H     1
# 549  EC  05/05/2025  15:00     Solihull   Dag and Red     1     1   D     0
# 550  EC  05/05/2025  15:00       Sutton        Woking     1     1   D     0
# 551  EC  05/05/2025  15:00   Wealdstone       Halifax     3     1   H     3
#
# ...

# %% [markdown]
# # Multiple Seasons

# %%
leagues = ['E0','E2','E3']
frames = []
for league in leagues:
  for season in range(20,25):
    df = pd.read_csv(root +str(season)+str(season+1)+'/'+league+'.csv' ,encoding='unicode_escape')
    df.insert(1,'season',season)
    frames.append(df)

# %%
len(frames)
# Out:
# 15

# %%
frames[0]
# Out:
#     Div  season        Date   Time          HomeTeam        AwayTeam  FTHG  \
# 0    E0      20  12/09/2020  12:30            Fulham         Arsenal     0
# 1    E0      20  12/09/2020  15:00    Crystal Palace     Southampton     1
# 2    E0      20  12/09/2020  17:30         Liverpool           Leeds     4
# 3    E0      20  12/09/2020  20:00          West Ham       Newcastle     0
# 4    E0      20  13/09/2020  14:00         West Brom       Leicester     0
# ..   ..     ...         ...    ...               ...             ...   ...
# 375  E0      20  23/05/2021  16:00         Liverpool  Crystal Palace     2
# 376  E0      20  23/05/2021  16:00          Man City         Everton     5
# 377  E0      20  23/05/2021  16:00  Sheffield United         Burnley     1
# 378  E0      20  23/05/2021  16:00          West Ham     Southampton     3
# 379  E0      20  23/05/2021  16:00            Wolves      Man United     1
#
# ...

# %%
frames[14]
# Out:
#     ï»¿Div  season        Date   Time        HomeTeam            AwayTeam  \
# 0       E3      24  09/08/2024  20:00    Chesterfield             Swindon
# 1       E3      24  10/08/2024  15:00   AFC Wimbledon          Colchester
# 2       E3      24  10/08/2024  15:00          Barrow               Crewe
# 3       E3      24  10/08/2024  15:00      Cheltenham      Newport County
# 4       E3      24  10/08/2024  15:00       Doncaster          Accrington
# ..     ...     ...         ...    ...             ...                 ...
# 547     E3      24  03/05/2025  15:00       Morecambe           Harrogate
# 548     E3      24  03/05/2025  15:00  Newport County            Tranmere
# 549     E3      24  03/05/2025  15:00    Notts County           Doncaster
# 550     E3      24  03/05/2025  15:00       Port Vale          Gillingham
# 551     E3      24  03/05/2025  15:00         Swindon  Milton Keynes Dons
#
#      FTHG  FTAG FTR  HTHG  ...  B365CAHH B365CAHA PCAHH  PCAHA  MaxCAHH  \
# ...

# %% [markdown]
# # Organize all the data in a dictionary

# %%
# create a dictionary with original name of league as key
dict_countries = {
              'Spanish La Liga':'SP1', 'Spanish Segunda Division':'SP2',
              'German Bundesliga':'D1',
              'English Premier League':'E0', 'English League 1':'E2', 'English League 2':'E3',
             }

# %%
dict_countries['Spanish La Liga']
# Out:
# 'SP1'

# %%
dict_historical_data = {}
for league in dict_countries:
    frames = [] # one dataframe per league
    for season in range(20, 25):
        df = pd.read_csv(root + str(season) + str(season+1) + "/" + dict_countries[league]+ ".csv")
        df.insert(1, 'season', season)
        frames.append(df)
    df_frames = pd.concat(frames) # storing all seasons of a league in a single dataframe
    dict_historical_data[league] = df_frames # assigning dataframe to a new dictionary
    # Loop through all leagues and seasons. For each league,;oad CSVs for multiple seasons. Add a season column to each file.Combine all seasons into one dataframe.Store that dataframe into a dictionary under its league code,

# %%
dict_historical_data['English Premier League']
# Out:
#     Div  season        Date   Time        HomeTeam     AwayTeam  FTHG  FTAG  \
# 0    E0      20  12/09/2020  12:30          Fulham      Arsenal     0     3
# 1    E0      20  12/09/2020  15:00  Crystal Palace  Southampton     1     0
# 2    E0      20  12/09/2020  17:30       Liverpool        Leeds     4     3
# 3    E0      20  12/09/2020  20:00        West Ham    Newcastle     0     2
# 4    E0      20  13/09/2020  14:00       West Brom    Leicester     0     3
# ..   ..     ...         ...    ...             ...          ...   ...   ...
# 375  E0      24  25/05/2025  16:00       Newcastle      Everton     0     1
# 376  E0      24  25/05/2025  16:00   Nott'm Forest      Chelsea     0     1
# 377  E0      24  25/05/2025  16:00     Southampton      Arsenal     1     2
# 378  E0      24  25/05/2025  16:00       Tottenham     Brighton     1     4
# 379  E0      24  25/05/2025  16:00          Wolves    Brentford     1     1
#
# ...
